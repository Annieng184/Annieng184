# %% [markdown]
# <a href="https://colab.research.google.com/github/Annieng184/Annieng184/blob/main/Nguyen_Ha_Trang_Intermediate_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)

# %% [markdown]
# # M2.1-E2 Intermediate SQL

# %%
#@title Before you start, please login with the same email you have registered for the course {display-mode: "form"}

# !pip install -q cspyclient
import cspyclient as cs

submission = cs.Submission.initialize_submission('626118be7e51f4001f190df0')

submission.register_student()
# Out:
#      |████████████████████████████████| 48 kB 3.7 MB/s
#      |████████████████████████████████| 4.1 MB 21.7 MB/s
# HTML(value='\n            Please enter the email that you used to register for the course.<br />\n            …
# Text(value='', description='Your email', placeholder='Email..')
# Button(button_style='success', description='Submit', icon='paper-plane', style=ButtonStyle(), tooltip='Submit'…
# Output()

# %% [markdown]
# **Import data and libraries**

# %%
import sqlite3
import pandas as pd

# !wget -q -c 'https://raw.githubusercontent.com/dhminh1024/practice_datasets/master/chinook.db'
conn = sqlite3.connect('chinook.db')

# %% [markdown]
# Here is the schema for this dataset.
#
# ![](https://i.imgur.com/kCaiMK5.png)

# %% [markdown]
# ## PART I: Easy (40 pts)

# %% [markdown]
# ### Question 1 (SQL - 5 pts)

# %%
query = """SELECT artists.name
FROM artists 
left JOIN albums on artists.artistid = albums.artistid
where albums.artistid is null
order by artists.name
"""
pd.read_sql_query(query, conn)
# Out:
#                                                  Name
# 0                                        A Cor Do Som
# 1   Academy of St. Martin in the Fields, Sir Nevil...
# 2         Aerosmith & Sierra Leone's Refugee Allstars
# 3                                       Avril Lavigne
# 4                                             Azymuth
# ..                                                ...
# 66                             Vinícius E Odette Lara
# 67                           Vinícius E Qurteto Em Cy
# 68                                         Whitesnake
# 69                                                Xis
# 70                                     Youssou N'Dour
#
# [71 rows x 1 columns]

# %%
#@title Run this to start question 1

submission.generate_question(0, globals(), height='100px')
# Out:
# Find artists who don't have any albums.
#
# Your resulting table should have artist names only.
#
# Sort by artist names alphabetically.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 2 (SQL - 5 pts)

# %%
query = """SELECT invoicedate, count(*) as number_of_bills
FROM invoices 
GROUP BY invoicedate
ORDER BY number_of_bills desc, invoicedate desc
limit 1
"""
pd.read_sql_query(query, conn)
# Out:
#            InvoiceDate  number_of_bills
# 0  2013-12-04 00:00:00                2

# %%
#@title Run this to start question 2

submission.generate_question(1, globals(), height='100px')
# Out:
# Find the date that has the most invoices.
#
# Your resulting table should have invoice date and number of bills on that day.
#
# If there are multiple dates that have the same number of bill, show the latest date only.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 3 (SQL - 5 pts)

# %%
query = """SELECT genres.name, count(*) as number_of_tracks
FROM tracks
JOIN genres on genres.genreid = tracks.genreid
GROUP BY genres.name
ORDER BY genres.name
"""
pd.read_sql_query(query, conn)
# Out:
#                   Name  number_of_tracks
# 0          Alternative                40
# 1   Alternative & Punk               332
# 2                Blues                81
# 3           Bossa Nova                15
# 4            Classical                74
# 5               Comedy                17
# 6                Drama                64
# 7       Easy Listening                24
# 8    Electronica/Dance                30
# 9          Heavy Metal                28
# 10         Hip Hop/Rap                35
# 11                Jazz               130
# 12               Latin               579
# 13               Metal               374
# 14               Opera                 1
# 15                 Pop                48
# 16            R&B/Soul                61
# 17              Reggae                58
# 18                Rock              1297
# 19       Rock And Roll                12
# 20    Sci Fi & Fantasy                26
# 21     Science Fiction                13
# ...

# %%
#@title Run this to start question 3

submission.generate_question(2, globals(), height='100px')
# Out:
# Find the number of music tracks in each genre.
#
# Your resulting table should have the genre name and the number of tracks for each genre.
#
# Sort by the genre names alphabetically.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 4 (SQL - 5 pts)

# %%
query = """SELECT t.trackid, t.name
FROM genres as g
JOIN tracks as t USING(genreid)
where g.name != 'Rock'
ORDER By t.name
"""
pd.read_sql_query(query, conn)
# Out:
#       TrackId                                               Name
# 0        2918                                                "?"
# 1        3412  "Eine Kleine Nachtmusik" Serenade In G, K. 525...
# 2         109                                            #1 Zero
# 3        3254                                           #9 Dream
# 4         602                                    'Round Midnight
# ...       ...                                                ...
# 2201      333              É que Nessa Encarnação Eu Nasci Manga
# 2202     3496    Étude 1, In C Major - Preludio (Presto) - Liszt
# 2203     2078                                             Óculos
# 2204     1073                                Óia Eu Aqui De Novo
# 2205     1077                                Último Pau-De-Arara
#
# [2206 rows x 2 columns]

# %%
#@title Run this to start question 4

submission.generate_question(3, globals(), height='100px')
# Out:
# Find all tracks that are ***NOT*** Rock music.
#
# Your resulting table should have the track IDs and names.
#
# Sort by track names alphabetically.
#
# You should only use JOIN.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %%
query = """SELECT FirstName, LastName, InvoiceId, InvoiceDate, BillingCountry
FROM invoices as i
JOIN customers as c using(customerid)
Where billingcountry = 'Brazil'
ORDER BY LastName
"""
pd.read_sql_query(query, conn)
# Out:
#     FirstName   LastName  InvoiceId          InvoiceDate BillingCountry
# 0     Roberto    Almeida         34  2009-05-23 00:00:00         Brazil
# 1     Roberto    Almeida        155  2010-11-14 00:00:00         Brazil
# 2     Roberto    Almeida        166  2010-12-25 00:00:00         Brazil
# 3     Roberto    Almeida        221  2011-08-25 00:00:00         Brazil
# 4     Roberto    Almeida        350  2013-03-31 00:00:00         Brazil
# 5     Roberto    Almeida        373  2013-07-03 00:00:00         Brazil
# 6     Roberto    Almeida        395  2013-10-05 00:00:00         Brazil
# 7        Luís  Gonçalves         98  2010-03-11 00:00:00         Brazil
# 8        Luís  Gonçalves        121  2010-06-13 00:00:00         Brazil
# 9        Luís  Gonçalves        143  2010-09-15 00:00:00         Brazil
# 10       Luís  Gonçalves        195  2011-05-06 00:00:00         Brazil
# 11       Luís  Gonçalves        316  2012-10-27 00:00:00         Brazil
# ...

# %% [markdown]
# ### Question 5 (SQL - 5 pts)

# %%
#@title Run this to start question 5

submission.generate_question(4, globals(), height='100px')
# Out:
# Find the Invoices of customers who are from Brazil.
#
# Your resulting table should have the customer first names, last names, Invoice IDs, Invoice dates, and billing countries.
#
# Sort by the customer last names alphabetically.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 6 (SQL - 5 pts)

# %%
query = """SELECT invoiceid, invoicedate, e.firstname, e.lastname 
FROM invoices as i
JOIN customers as c using(customerid)
JOIN employees as e on c.supportrepid = e.employeeid
where title = 'Sales Support Agent'
ORDER BY invoicedate desc, e.firstname, e.lastname
"""
pd.read_sql_query(query, conn)
# Out:
#      InvoiceId          InvoiceDate FirstName LastName
# 0          412  2013-12-22 00:00:00      Jane  Peacock
# 1          411  2013-12-14 00:00:00      Jane  Peacock
# 2          410  2013-12-09 00:00:00  Margaret     Park
# 3          409  2013-12-06 00:00:00      Jane  Peacock
# 4          408  2013-12-05 00:00:00     Steve  Johnson
# ..         ...                  ...       ...      ...
# 407          5  2009-01-11 00:00:00  Margaret     Park
# 408          4  2009-01-06 00:00:00     Steve  Johnson
# 409          3  2009-01-03 00:00:00  Margaret     Park
# 410          2  2009-01-02 00:00:00  Margaret     Park
# 411          1  2009-01-01 00:00:00     Steve  Johnson
#
# [412 rows x 4 columns]

# %%
#@title Run this to start question 6

submission.generate_question(5, globals(), height='100px')
# Out:
# Find the invoices that were supported by a Sales Support Agent employee.
#
# Your resulting table should have the invoice ID, invoice date, the agent's first name and last name.
#
# Sort by invoice date from latest to earliest, then by employee first name then last name.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 7 (SQL - 10 pts)

# %%
query = """SELECT e.firstname, e.lastname, e.title, count(customerid) as number_of_customers
FROM employees as e
left JOIN customers as c on e.employeeid = c.supportrepid
group by e.employeeid
ORDER BY number_of_customers, e.lastname
"""
pd.read_sql_query(query, conn)
# Out:
#   FirstName  LastName                Title  number_of_customers
# 0    Andrew     Adams      General Manager                    0
# 1     Laura  Callahan             IT Staff                    0
# 2     Nancy   Edwards        Sales Manager                    0
# 3    Robert      King             IT Staff                    0
# 4   Michael  Mitchell           IT Manager                    0
# 5     Steve   Johnson  Sales Support Agent                   18
# 6  Margaret      Park  Sales Support Agent                   20
# 7      Jane   Peacock  Sales Support Agent                   21

# %%
#@title Run this to start question 7

submission.generate_question(6, globals(), height='100px')
# Out:
# Find the number of customers that each employee has supported.
#
# Your resulting table should have the employee first names and last names, their titles, and the number of customers they each served.
#
# Sort by the number of customers served from smallest to largest, then by the employee last names alphabetically.
#
# Remember to show *every* employee, even if they have served no customers.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ## PART II: Medium (30 pts)

# %% [markdown]
# ### Question 8 (SQL - 10 pts)

# %%
query = """SELECT FirstName, LastName, count(*) as number_of_invoices
FROM invoices JOIN customers using(customerid)
Group by customerid
having number_of_invoices >=2
"""
pd.read_sql_query(query, conn)
# Out:
#     FirstName      LastName  number_of_invoices
# 0        Luís     Gonçalves                   7
# 1      Leonie        Köhler                   7
# 2    François      Tremblay                   7
# 3       Bjørn        Hansen                   7
# 4   František   Wichterlová                   7
# 5      Helena          Holý                   7
# 6      Astrid        Gruber                   7
# 7        Daan       Peeters                   7
# 8        Kara       Nielsen                   7
# 9     Eduardo       Martins                   7
# 10  Alexandre         Rocha                   7
# 11    Roberto       Almeida                   7
# 12   Fernanda         Ramos                   7
# 13       Mark       Philips                   7
# 14   Jennifer      Peterson                   7
# 15      Frank        Harris                   7
# 16       Jack         Smith                   7
# 17   Michelle        Brooks                   7
# 18        Tim         Goyer                   7
# ...

# %%
#@title Run this to start question 8

submission.generate_question(7, globals(), height='100px')
# Out:
# Find customers who come back to buy music.
#
# >*Hint: number of invoices.*
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 9 (SQL - 10 pts)

# %%
query = """SELECT c.customerid, c.FirstName, c.LastName, SUM(i1.total) as total_paid
FROM invoices as i1 JOIN customers as c using(customerid)
group by customerid
order by total_paid desc
limit 1
"""
pd.read_sql_query(query, conn)
# Out:
#    CustomerId FirstName LastName  total_paid
# 0           6    Helena     Holý       49.62

# %%
#@title Run this to start question 9

submission.generate_question(8, globals(), height='100px')
# Out:
# Find the customer who paid the most based on their invoice.
#
# Your resulting table should have the customer's id, first name, last name and the total amount they paid.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 10 (SQL - 10 pts)

# %%
query = """SELECT e2.firstname as employee_name, e2.title as employee_title, e1.firstname as supervisor_name, e1.title as supervisor_title
FROM employees as e1 JOIN employees as e2 on e1.employeeid = e2.reportsto
ORDER BY employee_title

"""
pd.read_sql_query(query, conn)
# Out:
#   employee_name       employee_title supervisor_name supervisor_title
# 0       Michael           IT Manager          Andrew  General Manager
# 1        Robert             IT Staff         Michael       IT Manager
# 2         Laura             IT Staff         Michael       IT Manager
# 3         Nancy        Sales Manager          Andrew  General Manager
# 4          Jane  Sales Support Agent           Nancy    Sales Manager
# 5      Margaret  Sales Support Agent           Nancy    Sales Manager
# 6         Steve  Sales Support Agent           Nancy    Sales Manager

# %%
#@title Run this to start question 10

submission.generate_question(9, globals(), height='100px')
# Out:
# Find all employees and who they report to (a.k.a their supervisor).
#
# Your resulting table should have the employee first name and title, and their supervisor first name and title.
#
# Sort by the employee's title alphabetically.
#
# >*Hint 1: Look at the schema for the employees table. See the connection on the right side? Which fields does it connect?*
#
# >*Hint 2: Take a look at the column ReportsTo in the employees table.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ## PART III: Hard (30 pts)

# %% [markdown]
# ### Question 11 (SQL - 5 pts)

# %%
query = """SELECT a1.name as Artist_Name, sum(i.UnitPrice * i.Quantity) as Total_Revenue
FROM artists as a1 JOIN albums as a2 using(artistid)
JOIN tracks as t using(albumid)
JOIN invoice_items as i using(trackid)
group by artistid
order by total_revenue desc
limit 3

"""
pd.read_sql_query(query, conn)
# Out:
#    Artist_Name  Total_Revenue
# 0  Iron Maiden         138.60
# 1           U2         105.93
# 2    Metallica          90.09

# %%
#@title Run this to start question 11

submission.generate_question(10, globals(), height='100px')
# Out:
# Find the top 3 richest artists based on their revenue from invoices.
#
# The total revenue of 1 track can be calculated by: UnitPrice * Quantity.
#
# Your resulting table should have the artist names and their total income.
#
# Sort by the artists' income from highest to lowest.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 12 (SQL - 5 pts)

# %%
query = """SELECT strftime('%Y/%m', InvoiceDate) as invoice_month_year, COUNT(*) as number_of_invoices
FROM invoices
GROUP BY invoice_month_year
ORDER BY invoice_month_year
"""
pd.read_sql_query(query, conn)
# Out:
#    invoice_month_year  number_of_invoices
# 0             2009/01                   6
# 1             2009/02                   7
# 2             2009/03                   7
# 3             2009/04                   7
# 4             2009/05                   7
# 5             2009/06                   7
# 6             2009/07                   7
# 7             2009/08                   7
# 8             2009/09                   7
# 9             2009/10                   7
# 10            2009/11                   7
# 11            2009/12                   7
# 12            2010/01                   7
# 13            2010/02                   7
# 14            2010/03                   7
# 15            2010/04                   7
# 16            2010/05                   7
# 17            2010/06                   7
# 18            2010/07                   7
# 19            2010/08                   7
# 20            2010/09                   6
# ...

# %%
#@title Run this to start question 12

submission.generate_question(11, globals(), height='100px')
# Out:
# Find the number of invoices in every month over the years.
#
# Your resulting table should have the months in year, formatted as YYYY/MM, and the number of invoices for that month.
#
# Sort by the months from earliest to latest.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 13 (SQL - 5 pts)

# %%
query = """SELECT strftime('%Y', InvoiceDate) as Year, sum(total) as Total_Revenue
FROM invoices
GROUP BY year
ORDER BY year
"""
pd.read_sql_query(query, conn)
# Out:
#    Year  Total_Revenue
# 0  2009         449.46
# 1  2010         481.45
# 2  2011         469.58
# 3  2012         477.53
# 4  2013         450.58

# %%
#@title Run this to start question 13

submission.generate_question(12, globals(), height='100px')
# Out:
# Find the total revenue from invoices every year.
#
# Your resulting table should have the year number and the total revenue from invoices for each year.
#
# Sort by year from earliest to latest.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 14 (SQL - 5 pts)

# %%
query = """SELECT strftime('%m', InvoiceDate) as Month, sum(total) as Total_Revenue
FROM invoices
where strftime('%Y', InvoiceDate) == '2013'
GROUP BY month
ORDER BY Total_Revenue desc
limit 1
"""
pd.read_sql_query(query, conn)
# Out:
#   Month  Total_Revenue
# 0    11          49.62

# %%
#@title Run this to start question 14

submission.generate_question(13, globals(), height='100px')
# Out:
# Find the month with highest revenue in 2013.
#
# Your resulting table should have the month and the revenue in that month.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 15 (SQL - 5 pts)

# %%
query = """SELECT strftime('%Y', InvoiceDate) as Year, sum(total) as Total_Revenue
FROM invoices
GROUP BY Year
ORDER BY Total_Revenue desc
LIMIT 1
"""
pd.read_sql_query(query, conn)
# Out:
#    Year  Total_Revenue
# 0  2010         481.45

# %%
#@title Run this to start question 15

submission.generate_question(14, globals(), height='100px')
# Out:
# Find the year with the highest revenue from invoices.
#
# Your resulting table should have the year number and the revenue of that year.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()

# %% [markdown]
# ### Question 16 (SQL - 5 pts)

# %%
query = """SELECT a1.name, COUNT(DISTINCT a2.AlbumId) as Number_of_albums, COUNT(t.TrackId) as Number_of_tracks
FROM artists as a1 LEFT JOIN albums as a2 USING(ArtistId)
LEFT JOIN tracks as t USING(AlbumId)
Group BY a1.ArtistId
ORDER BY a1.Name

"""
pd.read_sql_query(query, conn)
# Out:
#                                                   Name  Number_of_albums  \
# 0                                         A Cor Do Som                 0
# 1                                                AC/DC                 2
# 2            Aaron Copland & London Symphony Orchestra                 1
# 3                                       Aaron Goldberg                 1
# 4    Academy of St. Martin in the Fields & Sir Nevi...                 1
# ..                                                 ...               ...
# 270                                                Xis                 0
# 271                                     Yehudi Menuhin                 1
# 272                                           Yo-Yo Ma                 1
# 273                                     Youssou N'Dour                 0
# 274                                     Zeca Pagodinho                 1
#
#      Number_of_tracks
# 0                   0
# 1                  18
# ...

# %%
#@title Run this to start question 16

submission.generate_question(15, globals(), height='100px')
# Out:
# Find the number of music albums and tracks for each artist.
#
# Your resulting table should have the artist name, their number of albums and number of tracks.
#
# Sort by artist names alphabetically.
# Textarea(value='', layout=Layout(height='100px', width='600px'), placeholder='YOUR_ANSWER_HERE')
# ...
# Output()
